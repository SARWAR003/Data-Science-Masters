# %%
print("this is my print stamt")
# Out:
# this is my print stamt

# %%
import logging

# %%
logging.basicConfig(filename = "test.log", level = logging.INFO)

# %%
logging.info("this is my line of execution")

# %%
logging.error("this is my error")

# %%
logging.critical("this is my critical")

# %%
logging.warning("this is my warning")

# %%
logging.shutdown()

# %%
logging.debug("this is my debug")

# %%
logging.noset("this is my noset")
# Out:
# -----------------------------------------------------------------------
# AttributeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7484\145785801.py in <module>
# ----> 1 logging.noset("this is my noset")
#
# AttributeError: module 'logging' has no attribute 'noset'

# %%
## THIS ALL ARE LAVEL 
1. NOSET
2. DEBUG
3. INFO
4. WARNING
5. ERROR
6. CRITICAL
# Out:
#   File "C:\Users\Mdgol\AppData\Local\Temp\ipykernel_7484\2005117409.py", line 2
#     1. NOSET
#        ^
# SyntaxError: invalid syntax

# %%
import logging

# %%
logging.basicConfig(filename = "test4.log",level = logging.DEBUG,format = '%(asctime)s %(message)s')

# %%
logging.info("this is my info log")

# %%
logging.debug("this is my debug log")

# %%
logging.warning("this is my warning log")

# %%
logging.error("this is my error log")

# %%
logging.shutdown()

# %%
import logging

# %%
logging.basicConfig(filename = "test5.log",level = logging.DEBUG, format = '%(asctime)s %(name)s %(lavelname)s %(message)s')

# %%
logging.warning("this is my warning log")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 436, in format
# ...

# %%
l = [1,2,3,3,[4,45,5],"sarwar","roy"]

# %%
l1_int = []
l2_str = []
for i in l :
    logging.info("this is the start of my first for loop{}".format(l))
    logging.info("this is the value of i an logging {}".format(i))
    if type(i) == list:
        for j in i :
            logging.info("logging my j {j} and i is {i}".format(i = i ,j = j))
            if type(j) ==int:
                l1_int.append(j)
                
    elif type(i) == int:
        l1_int.append(i)
        
        
    else :
        if type(i) == str:
            l2_str.append(i)
            
logging.info("this is my final with all int {l1}, with all str {l2}")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'lavelname'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Mdgol\anaconda3\lib\logging\__init__.py", line 436, in format
# ...

# %%
l1_int
# Out:
# [1, 2, 3, 3, 4, 45, 5]

# %%
l2_str
# Out:
# ['sarwar', 'roy']
